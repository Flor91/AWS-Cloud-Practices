# %%
import random

for i in range(100):
  for j in range(30):
    deviceTypes = ["FS-15", "LF-10", "PP-5"]
    device = "device-" + str(i)
    group = "group-" + str(i % 10)
    minute = j
    amps = 890 + random.randint(0, 30)
    voltage = 215 + random.randint(0, 10)
    temp1 = 45 + random.randint(0, 10)
    temp2 = 20 + random.randint(0, 20)
    weight1 = 40 + random.randint(0, 20)
    weight2 = 12 + random.randint(0, 5)
    flow = 35 + random.randint(0, 10)
    print(f"""{{"device": "{device}","group": "{group}", "devicetype": "{deviceTypes[(i%3)]}", "date": "01-04-2018T00:{minute}:00.000Z", "inputCurrent": {amps},"inputCurrentunit": "amp","inputVoltage": {voltage},"inputvoltageunit": "ac-v","temp1": {temp1},"temp1unit": "c","temp2": {temp2},"temp2unit": "c","scale1": {weight1},"scale1unit": "kg","scale2": {weight2},"scale2unit": "kg","flow": {flow},"flowunit": "m3/h"}}""")
# Out:
# {"device": "device-0","group": "group-0", "devicetype": "FS-15", "date": "01-04-2018T00:0:00.000Z", "inputCurrent": 912,"inputCurrentunit": "amp","inputVoltage": 219,"inputvoltageunit": "ac-v","temp1": 53,"temp1unit": "c","temp2": 31,"temp2unit": "c","scale1": 41,"scale1unit": "kg","scale2": 14,"scale2unit": "kg","flow": 44,"flowunit": "m3/h"}
# {"device": "device-0","group": "group-0", "devicetype": "FS-15", "date": "01-04-2018T00:1:00.000Z", "inputCurrent": 918,"inputCurrentunit": "amp","inputVoltage": 224,"inputvoltageunit": "ac-v","temp1": 51,"temp1unit": "c","temp2": 35,"temp2unit": "c","scale1": 45,"scale1unit": "kg","scale2": 16,"scale2unit": "kg","flow": 37,"flowunit": "m3/h"}
# ...
