# %% [markdown]
# ## Snapshot

# %%
#!aws ec2 create-snapshot --volume-id vol-0dcb7c5855b74cca2 \
#--tag-specifications 'ResourceType=snapshot,Tags=[{Key=Name,Value=leoF_snap}]' \
#--description "Es una prueba 2020"

# %% [markdown]
# ### Muestra la info de un snapshot especifico.

# %%
# !aws ec2 describe-volumes
# Out:
# {
#     "Volumes": [
#         {
#             "Attachments": [
#                 {
#                     "AttachTime": "2020-06-18T05:52:53.000Z",
#                     "Device": "/dev/xvda",
#                     "InstanceId": "i-01eff49ce13396990",
#                     "State": "attached",
#                     "VolumeId": "vol-02d907605b779fcb7",
#                     "DeleteOnTermination": true
#                 }
#             ],
#             "AvailabilityZone": "us-east-1c",
#             "CreateTime": "2020-06-18T05:52:53.453Z",
#             "Encrypted": false,
#             "Size": 8,
#             "SnapshotId": "snap-0bab229867b7e5bf3",
#             "State": "in-use",
#             "VolumeId": "vol-02d907605b779fcb7",
#             "Iops": 100,
#             "Tags": [
#                 {
#                     "Key": "Name",
#                     "Value": "NO PARA CCOSTA"
#                 }
#             ],
#             "VolumeType": "gp2",
# ...

# %% [markdown]
# ### Muestra la info de un snapshot especifico.

# %%
# !aws ec2 describe-snapshots --snapshot-ids snap-0a9aaaaf39adef3a8
# Out:
# {
#     "Snapshots": [
#         {
#             "Description": "Es una prueba 2020",
#             "Encrypted": false,
#             "OwnerId": "622305974757",
#             "Progress": "100%",
#             "SnapshotId": "snap-0a9aaaaf39adef3a8",
#             "StartTime": "2020-06-07T23:46:46.549Z",
#             "State": "completed",
#             "VolumeId": "vol-0dcb7c5855b74cca2",
#             "VolumeSize": 1,
#             "Tags": [
#                 {
#                     "Key": "Name",
#                     "Value": "leoF_snap"
#                 }
#             ]
#         }
#     ]
# }
